# %% [markdown]
# #Importing the libraries

# %%
# Import Basic Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #Loading the dataset

# %%
menu = pd.read_csv('India_Menu.csv')
menu.head()
# Out:
#        Category                   Items Per Serve Size  Energy (kCal)  \
# 0  Regular Menu        McVeggie™ Burger          168 g         402.05
# 1  Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2  Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
# 3  Regular Menu       Spicy Paneer Wrap          250 g         674.68
# 4  Regular Menu     American Veg Burger          177 g         512.17
#
#    Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0        10.24          13.83         5.34           0.16               2.49
# 1         8.50          11.31         4.27           0.20               1.47
# 2        20.29          39.45        17.12           0.18              21.85
# 3        20.96          39.10        19.73           0.26              40.93
# 4        15.30          23.45        10.51           0.17              25.24
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# ...

# %% [markdown]
# #Shape of the dataset

# %%
menu.shape
# Out:
# (141, 13)

# %%
menu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Category                141 non-null    object
#  1   Items                   141 non-null    object
#  2   Per Serve Size          141 non-null    object
#  3   Energy (kCal)           141 non-null    float64
#  4   Protein (g)             141 non-null    float64
#  5   Total fat (g)           141 non-null    float64
#  6   Sat Fat (g)             141 non-null    float64
#  7   Trans fat (g)           141 non-null    float64
#  8   Cholesterols (mg)       141 non-null    float64
#  9   Total carbohydrate (g)  141 non-null    float64
#  10  Total Sugars (g)        141 non-null    float64
#  11  Added Sugars (g)        141 non-null    float64
#  12  Sodium (mg)             140 non-null    float64
# dtypes: float64(10), object(3)
# memory usage: 14.4+ KB

# %%
menu.isnull().sum()
# Out:
# Category                  0
# Items                     0
# Per Serve Size            0
# Energy (kCal)             0
# Protein (g)               0
# Total fat (g)             0
# Sat Fat (g)               0
# Trans fat (g)             0
# Cholesterols (mg)         0
# Total carbohydrate (g)    0
# Total Sugars (g)          0
# Added Sugars (g)          0
# Sodium (mg)               1
# dtype: int64

# %% [markdown]
# Analysis:
#
#
# 1.  The dataset has 141 records (menu items)
# 2.  10 out of 13 attributes have the datatype float64
# 3.  3 out of 13 attributes have the object datatype
# 4.  Total memory usage of the dataset = 14.4+ KB
# 5.  Sodium attribute has 1 null value

# %% [markdown]
# #Effective Data Analysis

# %%
#Gives the entire summary of the dataset
menu.describe()
# Out:
#        Energy (kCal)  Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# count     141.000000   141.000000     141.000000   141.000000     141.000000
# mean      244.635461     7.493546       9.991702     4.997589       0.687163
# std       185.554837     8.336863      10.339511     4.900451       6.326136
# min         0.000000     0.000000       0.000000     0.000000       0.000000
# 25%       116.360000     0.650000       0.460000     0.280000       0.060000
# 50%       219.360000     4.790000       7.770000     4.270000       0.150000
# 75%       339.520000    10.880000      14.160000     7.280000       0.220000
# max       834.360000    39.470000      45.180000    20.460000      75.260000
#
#        Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# count         141.000000              141.000000        141.000000
# mean           26.350071               31.190284         15.464894
# std            50.334200               20.602044         15.690202
# ...

# %% [markdown]
# #Unique values in Category Column

# %%
menu.Category.unique()
# Out:
# array(['Regular Menu', 'Breakfast Menu', 'McCafe Menu', 'Desserts Menu',
#        'Gourmet Menu', 'Beverages Menu', 'Condiments Menu'], dtype=object)

# %%
menu.Category.value_counts()
# Out:
# McCafe Menu        51
# Regular Menu       36
# Beverages Menu     17
# Breakfast Menu     15
# Gourmet Menu       11
# Condiments Menu     9
# Desserts Menu       2
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category', data=menu)
plt.xticks(rotation=55)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# Analysis:
#
# 1.  The different types of MCD menus are - Regular Menu(36 items), Breakfast Menu(15 items), McCafe Menu(51 items), Desserts Menu(2 items), Gourmet Menu(11 items), Beverages Menu(17 items), Condiments Menu(9 items)
# 2.   From the graph we see that the Regular Menu and the McCafe Menu are consumed the most.
# 3.   From the graph we see that the Desserts Menu and Condiments Menu are consumed the least.

# %% [markdown]
# #Visualize Average Nutritions Value per Category

# %%
# Make a lis of all nutritions which u want to visualize
nutritions = ['Energy (kCal)', 'Protein (g)', 'Total fat (g)', 'Sat Fat (g)',
              'Trans fat (g)','Cholesterols (mg)', 'Total carbohydrate (g)',
              'Total Sugars (g)', 'Added Sugars (g)', 'Sodium (mg)']

# %%
plt.figure(figsize = (25,55))
for i, ntr in enumerate(nutritions):
    plt.subplot(7, 2, i+1)
    sns.barplot(x='Category', y=ntr, data=menu)
plt.xticks(rotation=55)
plt.show()

# %%
# Texual Description about above visualization
for ntr in nutritions:
    temp_list = menu.pivot_table(ntr, 'Category').sort_values(by=ntr, ascending=False)
    print('{}'.format(temp_list[:7]))
    print('-----------------------------------------------------')
# Out:
#                  Energy (kCal)
# Category
# Gourmet Menu        543.497273
# Regular Menu        367.737778
# McCafe Menu         183.679608
# Breakfast Menu      181.290000
# Desserts Menu       162.875000
# Beverages Menu      143.326471
# Condiments Menu      47.473333
# -----------------------------------------------------
#                  Protein (g)
# Category
# Gourmet Menu       21.684545
# Regular Menu       12.990833
# Breakfast Menu      7.636667
# McCafe Menu         4.295490
# Desserts Menu       2.815000
# Condiments Menu     0.731111
# Beverages Menu      0.268235
# -----------------------------------------------------
#                  Total fat (g)
# Category
# Gourmet Menu         27.671818
# Regular Menu         17.625833
# Breakfast Menu        7.735333
# McCafe Menu           5.945686
# Desserts Menu         5.255000
# Condiments Menu       3.876667
# Beverages Menu        0.308824
# -----------------------------------------------------
# ...

# %% [markdown]
# Analysis:
#
# 1. The above code cell prints top 3 categorical source for each nutrition listed
# 2. Also by onserving graphs we can get rich source of each nutrition

# %% [markdown]
# #Plot Average Calories each Category contains

# %%
sns.barplot(x='Category', y='Energy (kCal)', data=menu)
plt.xticks(rotation=55)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# Analysis:
#
# 1.  The above graph shows the calories that each type of menu has on an average.
#
# *   Regular Menu - around 360 kCal
# *   Breakfast Menu - around 200 kCal
# *   McCafe Menu - around 200 kCal
# *   Desserts Menu - around 190 kCal
# *   Gourmet Menu - around 550 kCal
# *   Beverages Menu - around 150 kCal
# *   Condiments Menu - around 50 kCal

# %% [markdown]
# #Plot which items contains which nutritions

# %%
# A function which can plot N Items which contains highest nutrition
# Change value of N as per convenience in visualization

def plot_item_vs_nutrition(nutrition, n):
    item = menu.groupby(menu[nutrition])['Items'].sum().sort_index()[-n:]
    plt.figure(figsize=(20,20))
    sns.barplot(item.index, item.values)

# %%
# Let's Start with Energy
plot_item_vs_nutrition('Energy (kCal)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Protein (g)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Total fat (g)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Sat Fat (g)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Trans fat (g)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Cholesterols (mg)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Total carbohydrate (g)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Total Sugars (g)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Added Sugars (g)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot_item_vs_nutrition('Sodium (mg)', 5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Analysis:
#
# 1. Energy:
# *  max - veg mharaja mac, chicken cheese lava burger (850)
# *  min - vedica matural mineral water, coke zero can (0)
#
# 2. protein:
# *  max - chicken maharaja mac, chunky chipotle american burger chicken (37.5)
# *  min - beverages (1)
# *  clearly chicken is the source of high protein
#
# 3. total fat:
# *  max - McSpicy''' Panner burger, chicken cheese lava burger (42.5)
# *  min - ice teas (2)
#
# 4. sat fat:
# *  max - spicy paneer wrap, McSpicy Premium veg Burger (20)
# *  min - beverages (0.1)
#
# 5. trans fat:
# * max - 5 piece Chicken Strips(75)
# * min - desserts(0)
#
# 6. cholestrol:
# * max - sausage Mc muffin with egg, McSpicy Premium Chicken Burger(300)
# * min - beverages (10)
#
# 7. total carbohyderates:
# * max - medium blackforest,veg maharaja mac (80)
# * min - english breakfast (1)
# * mainly because of more potatoes
#
# 8. total sugars:
# * max - large sprite, large fanta orange (60)
# * min - beverages (1)
# * clearly the content of sugar in carbonated drinks is high
#
# 9. added sugars:
# * max - large sprite, large fanta (60)
# * min - nuggets, fruit beverages (1)
# * overall the content of sugar is high in carbonated drinks
#
# 10. sodium:
# * max - beverages(0)
# * min - ghee rice with Mc Spicy Fried Chicken, Chunky Chipotle American burger chicken (2300)
